# %% [markdown]
# # Conversational Threads

# %% [markdown]
# Many LLM applications have a chatbot-like interface in which the user and the LLM application engage in a multi-turn conversation. In order to track these conversations, you can use the Threads feature in LangSmith.
#
# This is relevant to our RAG application, which should maintain context from prior conversations with users.

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["GROQ_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"  # If you don't set this, traces will go to the Default project

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../.env", override=True)
# Out:
# True

# %% [markdown]
# ### Group traces into threads

# %% [markdown]
# A Thread is a sequence of traces representing a single conversation. Each response is represented as its own trace, but these traces are linked together by being part of the same thread.
#
# To associate traces together, you need to pass in a special metadata key where the value is the unique identifier for that thread.
#
# The key value is the unique identifier for that conversation. The key name should be one of:
#
# - session_id
# - thread_id
# - conversation_id.
#
# The value should be a UUID.

# %%
import uuid
thread_id = uuid.uuid4()

# %%
import os
import openai
from langsmith import traceable
from typing import List
import nest_asyncio
from utils import get_vector_db_retriever

openai_client = openai.OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)
nest_asyncio.apply()
retriever = get_vector_db_retriever()

@traceable(run_type="chain")
def retrieve_documents(question: str):
    return retriever.invoke(question)

@traceable(run_type="chain")
def generate_response(question: str, documents):
    formatted_docs = "\n\n".join(doc.page_content for doc in documents)
    rag_system_prompt = """You are an assistant for question-answering tasks. 
    Use the following pieces of retrieved context to answer the latest question in the conversation. 
    If you don't know the answer, just say that you don't know. 
    Use three sentences maximum and keep the answer concise.
    """
    messages = [
        {
            "role": "system",
            "content": rag_system_prompt
        },
        {
            "role": "user",
            "content": f"Context: {formatted_docs} \n\n Question: {question}"
        }
    ]
    return call_openai(messages)

@traceable(run_type="llm")
def call_openai(
    messages: List[dict], model: str = "openai/gpt-oss-20b", temperature: float = 0.0
) -> str:
    return openai_client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )

@traceable(run_type="chain")
def langsmith_rag(question: str):
    documents = retrieve_documents(question)
    response = generate_response(question, documents)
    return response.choices[0].message.content

# %% [markdown]
# ### Now let's run our application twice with this thread_id

# %%
question = "How do I add metadata to a Trace?"
ai_answer = langsmith_rag(question, langsmith_extra={"metadata": {"thread_id": thread_id}})
print(ai_answer)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 question = "How do I add metadata to a Trace?"
# ----> 2 ai_answer = langsmith_rag(question, langsmith_extra={"metadata": {"thread_id": thread_id}})
#       3 print(ai_answer)
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langsmith\run_helpers.py:808, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     804         function_result = run_container["context"].run(
#     805             run_with_otel_context
#     806         )
#     807     else:
# --> 808         function_result = run_container["context"].run(
#     809             func, *args, **kwargs
#     810         )
#     811 except BaseException as e:
#     812     _cleanup_traceback(e)
#
# Cell In[7], line 51, in langsmith_rag(question)
#      49 @traceable(run_type="chain")
#      50 def langsmith_rag(question: str):
# ---> 51     documents = retrieve_documents(question)
#      52     response = generate_response(question, documents)
#      53     return response.choices[0].message.content
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langsmith\run_helpers.py:808, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     804         function_result = run_container["context"].run(
#     805             run_with_otel_context
#     806         )
#     807     else:
# --> 808         function_result = run_container["context"].run(
#     809             func, *args, **kwargs
#     810         )
#     811 except BaseException as e:
#     812     _cleanup_traceback(e)
#
# Cell In[7], line 17, in retrieve_documents(question)
#      15 @traceable(run_type="chain")
#      16 def retrieve_documents(question: str):
# ---> 17     return retriever.invoke(question)
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langchain_core\retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langchain_core\vectorstores\base.py:1045, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1043 kwargs_ = self.search_kwargs | kwargs
#    1044 if self.search_type == "similarity":
# -> 1045     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1046 elif self.search_type == "similarity_score_threshold":
#    1047     docs_and_similarities = (
#    1048         self.vectorstore.similarity_search_with_relevance_scores(
#    1049             query, **kwargs_
#    1050         )
#    1051     )
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langchain_community\vectorstores\sklearn.py:256, in SKLearnVectorStore.similarity_search(self, query, k, **kwargs)
#     253 def similarity_search(
#     254     self, query: str, k: int = DEFAULT_K, **kwargs: Any
#     255 ) -> List[Document]:
# --> 256     docs_scores = self.similarity_search_with_score(query, k=k, **kwargs)
#     257     return [doc for doc, _ in docs_scores]
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langchain_community\vectorstores\sklearn.py:238, in SKLearnVectorStore.similarity_search_with_score(self, query, k, **kwargs)
#     235 def similarity_search_with_score(
#     236     self, query: str, *, k: int = DEFAULT_K, **kwargs: Any
#     237 ) -> List[Tuple[Document, float]]:
# --> 238     query_embedding = self._embedding_function.embed_query(query)
#     239     indices_dists = self._similarity_index_search_with_score(
#     240         query_embedding, k=k, **kwargs
#     241     )
#     242     return [
#     243         (
#     244             Document(
#    (...)    250         for idx, dist in indices_dists
#     251     ]
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langchain_ollama\embeddings.py:335, in OllamaEmbeddings.embed_query(self, text)
#     333 def embed_query(self, text: str) -> list[float]:
#     334     """Embed query text."""
# --> 335     return self.embed_documents([text])[0]
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\langchain_ollama\embeddings.py:325, in OllamaEmbeddings.embed_documents(self, texts)
#     320     msg = (
#     321         "Ollama sync client is not initialized. "
#     322         "Make sure the model was properly constructed."
#     323     )
#     324     raise RuntimeError(msg)
# --> 325 return self._client.embed(
#     326     self.model,
#     327     texts,
#     328     dimensions=self.dimensions,
#     329     options=self._default_params,
#     330     keep_alive=self.keep_alive,
#     331 )["embeddings"]
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\ollama\_client.py:415, in Client.embed(self, model, input, truncate, options, keep_alive, dimensions)
#     406 def embed(
#     407   self,
#     408   model: str = '',
#    (...)    413   dimensions: Optional[int] = None,
#     414 ) -> EmbedResponse:
# --> 415   return self._request(
#     416     EmbedResponse,
#     417     'POST',
#     418     '/api/embed',
#     419     json=EmbedRequest(
#     420       model=model,
#     421       input=input,
#     422       truncate=truncate,
#     423       options=options,
#     424       keep_alive=keep_alive,
#     425       dimensions=dimensions,
#     426     ).model_dump(exclude_none=True),
#     427   )
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\ollama\_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~\Desktop\hexon\learn_ai\venv\Lib\site-packages\ollama\_client.py:145, in Client._request_raw(self, *args, **kwargs)
#     143   raise ResponseError(e.response.text, e.response.status_code) from None
#     144 except httpx.ConnectError:
# --> 145   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ConnectionError: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download

# %%
question = "How can I add tags to a Trace?"
ai_answer = langsmith_rag(question, langsmith_extra={"metadata": {"thread_id": thread_id}})
print(ai_answer)

# %% [markdown]
# ### Let's take a look in LangSmith!
